# %%
from google.colab import drive
import os

drive.mount('/content/drive')

# %cd /content/drive/MyDrive/HALXIITI/Digital_Twin_HALXIITI
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/HALXIITI/Digital_Twin_HALXIITI

# %%
import pandas as pd

# %%
train = pd.read_csv('/content/drive/MyDrive/HALXIITI/train.csv')
tj = pd.read_csv('/content/drive/MyDrive/HALXIITI/turbojet_complete_dataset.csv')
gt = pd.read_csv('/content/drive/MyDrive/HALXIITI/ground_truth.csv')


print("training data's info: \n",train.info())
print("ground truth data's info: \n",gt.info())
print("turbojet data's info: \n",tj.info())
train.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   EngineID       240 non-null    int64
#  1   Cycle          240 non-null    int64
#  2   Altitude_m     240 non-null    float64
#  3   Mach           240 non-null    float64
#  4   Tamb_K         240 non-null    float64
#  5   Pamb_Pa        240 non-null    float64
#  6   RPM_rev_min    240 non-null    float64
#  7   FuelFlow_kg_s  240 non-null    float64
#  8   P2_Pa          240 non-null    float64
#  9   T2_K           240 non-null    float64
#  10  P3_Pa          240 non-null    float64
#  11  T3_K           240 non-null    float64
#  12  P4_Pa          240 non-null    float64
#  13  T4_K           240 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 26.4 KB
# training data's info:
#  None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   EngineID          300 non-null    int64
#  1   Cycle             300 non-null    int64
#  2   CompressorHealth  300 non-null    float64
#  3   CombustorHealth   300 non-null    float64
#  4   TurbineHealth     300 non-null    float64
#  5   OverallHealth     300 non-null    float64
#  6   Thrust_N          300 non-null    float64
#  7   TSFC_g_N_s        300 non-null    float64
# dtypes: float64(6), int64(2)
# memory usage: 18.9 KB
# ground truth data's info:
#  None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   EngineID          300 non-null    int64
#  1   Cycle             300 non-null    int64
#  2   Altitude_m        300 non-null    float64
#  3   Mach              300 non-null    float64
#  4   Tamb_K            300 non-null    float64
#  5   Pamb_Pa           300 non-null    float64
#  6   RPM_rev_min       300 non-null    float64
#  7   FuelFlow_kg_s     300 non-null    float64
#  8   P2_Pa             300 non-null    float64
#  9   T2_K              300 non-null    float64
#  10  P3_Pa             300 non-null    float64
#  11  T3_K              300 non-null    float64
#  12  P4_Pa             300 non-null    float64
#  13  T4_K              300 non-null    float64
#  14  CompressorHealth  300 non-null    float64
#  15  CombustorHealth   300 non-null    float64
#  16  TurbineHealth     300 non-null    float64
#  17  OverallHealth     300 non-null    float64
#  18  Thrust_N          300 non-null    float64
#  19  TSFC_g_N_s        300 non-null    float64
# dtypes: float64(18), int64(2)
# memory usage: 47.0 KB
# turbojet data's info:
#  None
#    EngineID  Cycle    Altitude_m      Mach      Tamb_K       Pamb_Pa  \
# 0         8     23   6640.033133  0.512847  245.789718  43781.864868
# 1         2     30  10261.418389  0.785128  224.870318  25756.707037
# 2         1      7   5057.250681  0.737485  253.827676  52949.948155
# 3         7      6   7702.423630  0.207260  234.787849  37063.492548
# 4         6     24   2260.803864  0.069631  271.693084  77656.763317
#
#     RPM_rev_min  FuelFlow_kg_s          P2_Pa        T2_K          P3_Pa  \
# 0  40683.465163       1.519539   97665.981479  328.153516   92151.695661
# 1  65363.486058       1.709128  147492.615101  426.700110  138958.020973
# 2  73201.933649       0.212161  453907.653794  493.268755  426229.561589
# 3  57371.271661       0.863692  161685.159452  380.097524  153506.692712
# 4  64453.978048       0.896952  342471.435319  469.040062  320971.536250
#
#           T3_K          P4_Pa         T4_K
# 0  3311.506678   82792.898121  3180.498276
# 1  2039.285853   88415.286814  1824.004689
# 2   705.299064   94760.519988   443.874508
# 3  1450.375762  102731.684308  1302.540082
# 4  1345.341125  160942.155348  1098.339112

# %%
print(train.describe())
print(tj.describe())
print(gt.describe())
# Out:
#          EngineID       Cycle    Altitude_m        Mach      Tamb_K  \
# count  240.000000  240.000000    240.000000  240.000000  240.000000
# mean     5.495833   15.412500   5932.482155    0.449417  249.695588
# std      2.879734    8.643125   3410.615931    0.258354   22.390107
# min      1.000000    1.000000     17.793517    0.002933  208.171037
# 25%      3.000000    8.000000   2825.704326    0.232121  232.843642
# 50%      5.000000   15.000000   6182.011554    0.459755  246.852949
# 75%      8.000000   23.000000   8543.266807    0.672162  269.992204
# max     10.000000   30.000000  12053.311094    0.896234  294.517485
#
#              Pamb_Pa   RPM_rev_min  FuelFlow_kg_s          P2_Pa        T2_K  \
# count     240.000000    240.000000     240.000000     240.000000  240.000000
# mean    51911.129610  55653.434853       1.067524  231380.388659  402.221744
# std     23766.713094  14773.617872       0.545056  163124.717947   79.473437
# min     19143.731778  30120.130720       0.200541   23345.186295  212.210181
# 25%     32859.337232  42700.398986       0.588252  115111.328906  350.457724
# 50%     46528.910402  55928.185998       1.030440  180187.969120  404.569191
# 75%     71644.554006  69536.317189       1.525964  298065.431103  455.882139
# max    102258.842120  80941.638133       1.997792  712511.048036  598.656431
#
#                P3_Pa         T3_K          P4_Pa         T4_K
# count     240.000000   240.000000     240.000000   240.000000
# mean   219599.604315  1976.853157  130355.751812  1816.903198
# std    155062.533803  1072.666617   80705.729864  1118.601934
# min     22082.767135   622.358998   21888.638341   402.832633
# 25%    109535.237324  1113.824615   69373.175907   947.753381
# 50%    173312.059386  1773.790545  109214.584301  1538.761059
# 75%    282417.868554  2550.051582  172807.125961  2394.535049
# max    671962.173021  6233.529064  462626.563838  6202.058881
#         EngineID       Cycle    Altitude_m        Mach      Tamb_K  \
# count  300.00000  300.000000    300.000000  300.000000  300.000000
# mean     5.50000   15.500000   5830.980490    0.447013  250.260899
# std      2.87708    8.669903   3353.584110    0.257749   21.976754
# min      1.00000    1.000000     17.793517    0.002933  208.171037
# 25%      3.00000    8.000000   2968.436813    0.232121  233.740481
# 50%      5.50000   15.500000   6001.265584    0.446696  248.771944
# 75%      8.00000   23.000000   8472.684935    0.665959  269.197223
# max     10.00000   30.000000  12053.311094    0.902138  294.517485
#
#              Pamb_Pa   RPM_rev_min  FuelFlow_kg_s          P2_Pa        T2_K  \
# count     300.000000    300.000000     300.000000     300.000000  300.000000
# mean    52449.900082  54854.217350       1.066888  227512.356003  398.904877
# std     23229.245316  14762.492706       0.541926  160059.164077   79.383330
# min     19143.731778  30120.130720       0.200541   23345.186295  212.210181
# 25%     33452.000682  41995.730102       0.607030  112256.739346  346.021381
# 50%     47142.141115  54918.561223       1.025178  176959.280744  401.075039
# 75%     70475.667384  68012.979967       1.525964  295973.817097  452.227999
# max    102258.842120  80941.638133       1.997792  712511.048036  598.656431
#
#                P3_Pa         T3_K          P4_Pa         T4_K  \
# count     300.000000   300.000000     300.000000   300.000000
# mean   216036.267720  2012.764053  129451.437887  1855.868934
# std    152289.083699  1116.677298   77741.549858  1161.814078
# min     22082.767135   622.358998   21888.638341   402.832633
# 25%    106051.160731  1139.937923   70717.498743   953.323622
# 50%    169811.004012  1773.790545  109214.584301  1560.387879
# 75%    281351.756165  2575.082839  172705.581613  2411.910896
# max    671962.173021  6687.485279  462626.563838  6571.717578
#
#        CompressorHealth  CombustorHealth  TurbineHealth  OverallHealth  \
# count        300.000000       300.000000     300.000000     300.000000
# mean           0.894607         0.963764       0.928672       0.925574
# std            0.073054         0.026750       0.051625       0.051092
# min            0.720830         0.888227       0.789415       0.800893
# 25%            0.837755         0.945013       0.893912       0.884696
# 50%            0.902873         0.968586       0.936514       0.931871
# 75%            0.958689         0.986310       0.972544       0.970745
# max            0.998012         0.999503       0.998727       0.998551
#
#            Thrust_N  TSFC_g_N_s
# count    300.000000  300.000000
# mean   46855.665165    0.021752
# std    17196.895497    0.006407
# min    13325.083980    0.009898
# 25%    34251.454300    0.016432
# 50%    45811.527115    0.021369
# 75%    60116.925839    0.026109
# max    88729.320822    0.038128
#         EngineID       Cycle  CompressorHealth  CombustorHealth  \
# count  300.00000  300.000000        300.000000       300.000000
# mean     5.50000   15.500000          0.894607         0.963764
# std      2.87708    8.669903          0.073054         0.026750
# min      1.00000    1.000000          0.720830         0.888227
# 25%      3.00000    8.000000          0.837755         0.945013
# 50%      5.50000   15.500000          0.902873         0.968586
# 75%      8.00000   23.000000          0.958689         0.986310
# max     10.00000   30.000000          0.998012         0.999503
#
#        TurbineHealth  OverallHealth      Thrust_N  TSFC_g_N_s
# count     300.000000     300.000000    300.000000  300.000000
# mean        0.928672       0.925574  46855.665165    0.021752
# std         0.051625       0.051092  17196.895497    0.006407
# min         0.789415       0.800893  13325.083980    0.009898
# 25%         0.893912       0.884696  34251.454300    0.016432
# 50%         0.936514       0.931871  45811.527115    0.021369
# 75%         0.972544       0.970745  60116.925839    0.026109
# max         0.998727       0.998551  88729.320822    0.038128

# %%
from google.colab import userdata

token = userdata.get('GH_TOKEN')
username = "Aditya-16may"
repo_name = "Digital_Twin_HALXIITI"

# !git remote set-url origin https://{username}:{token}@github.com/{username}/{repo_name}.git


# !git add digital_twin.ipynb
# !git commit -m "Updated model progress and cleaned up workspace setup"
# !git push origin main
# Out:
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@54239f049bdd.(none)')
# Everything up-to-date
