# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd {repo_name}
# !ls

# %%
import pandas as pd

# %%
train = pd.read_csv('/content/drive/MyDrive/HALXIITI/train.csv')
tj = pd.read_csv('/content/drive/MyDrive/HALXIITI/turbojet_complete_dataset.csv')
gt = pd.read_csv('/content/drive/MyDrive/HALXIITI/ground_truth.csv')


print("training data's info: \n",train.info())
print("ground truth data's info: \n",gt.info())
print("turbojet data's info: \n",tj.info())
train.head()

# %%
import os
from google.colab import userdata

# 1. Fetch your hidden token safely
try:
    token = userdata.get('GH_TOKEN')
    if not token:
        raise ValueError("Token value is empty. Please check your Colab Secrets.")
except Exception as e:
    print(f"Secret Error: {e}")
    print("Ensure the secret name is exactly 'GH_TOKEN' and notebook access is toggled ON.")

username = "Aditya-16may"
repo_name = "Digital_Twin_HALXIITI"

# 2. Reset the local Git configuration entirely
# %cd /content/drive/MyDrive/HALXIITI/Digital_Twin_HALXIITI
# !rm -rf .git
# !git init
# !git checkout -b main

# 3. Configure identity and point to the secure remote URL
# !git config --global user.email "araj26976@gmail.com"
# !git config --global user.name "Aditya-16may"
# !git remote add origin https://{username}:{token}@github.com/{username}/{repo_name}.git

# 4. Commit and force-push the clean notebook
# !git add digital_twin.ipynb
# !git commit -m "Initial clean commit without token history"
# !git push -u origin main --force
